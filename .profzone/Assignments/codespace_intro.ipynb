# %% [markdown]
# # 📘 CodeSpace Intro
#
# Welcome to your first Jupyter notebook in CodeSpace's! If it's not, that's ok, this will be real easy.

# %% [markdown]
# ## ✅ Learning Goals
# - Run cells in a notebook
# - Edit Markdown and code
# - Save a copy to your own Drive

# %%
# 👋 Try running this cell!
print('Hello, Python Spatial World!')
# Out:
# Hello, Python Spatial World!

# %% [markdown]
# ## ✏️ Your Turn
# Modify the code below to print your name.

# %%
print('Terry')
# Out:
# Terry

# %% [markdown]
# ## 💾 Save a Copy
# - Go to **File > Save a copy in Colabs**.
# - Make sure it changed on your github repo.
#
# Move it to your `completed` folder.

# %%
import geojsonio
import json
from IPython.display import display

with open('campus_world.geojson') as f:
    geojson_data = json.load(f)

# Convert the dictionary to a JSON string if needed, 
# though the library often handles the dict directly
# contents = json.dumps(geojson_data) 

# Embed the geojson.io map
# The display function is an alias for embed() in the library
display(geojsonio.embed(geojson_data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 14
#       6     geojson_data = json.load(f)
#       8 # Convert the dictionary to a JSON string if needed,
#       9 # though the library often handles the dict directly
#      10 # contents = json.dumps(geojson_data)
#      11
#      12 # Embed the geojson.io map
#      13 # The display function is an alias for embed() in the library
# ---> 14 display(geojsonio.embed(geojson_data))
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/geojsonio/geojsonio.py:57, in embed(contents, width, height, *args, **kwargs)
#      44 """
#      45 Embed geojson.io in an iframe in Jupyter/IPython notebook.
#      46
#    (...)     53
#      54 """
#      55 from IPython.display import HTML
# ---> 57 url = make_url(contents, *args, **kwargs)
#      58 html = '<iframe src={url} width={width} height={height}></iframe>'.format(
#      59     url=url, width=width, height=height)
#      60 return HTML(html)
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/geojsonio/geojsonio.py:89, in make_url(contents, domain, force_gist, size_for_gist)
#      63 def make_url(contents, domain=DEFAULT_DOMAIN, force_gist=False,
#      64              size_for_gist=MAX_URL_LEN):
#      65     """
#      66     Returns the URL to open given the domain and contents.
#      67
#    (...)     87
#      88     """
# ---> 89     contents = make_geojson(contents)
#      90     if len(contents) <= size_for_gist and not force_gist:
#      91         url = data_url(contents, domain)
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/geojsonio/geojsonio.py:124, in make_geojson(contents)
#     122     for i, f in enumerate(feature_iter):
#     123         if not hasattr(f, '__geo_interface__'):
# --> 124             raise ValueError('Unknown type at index {0}'.format(i))
#     125         features.append(_geo_to_feature(f))
#     127 data = {'type': 'FeatureCollection', 'features': features}
#
# ValueError: Unknown type at index 0

# %%
from geojsonio import display

with open('campus_world.geojson') as f:
    contents = f.read()
    display(contents)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from geojsonio import display
# ----> 3 with open('campus_world.geojson') as f:
#       4     contents = f.read()
#       5     display(contents)
#
# File /Volumes/X9Pro/Sync/__currentCourses/4543-5993-Spatial-Data/.venv/lib/python3.13/site-packages/IPython/core/interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'campus_world.geojson'

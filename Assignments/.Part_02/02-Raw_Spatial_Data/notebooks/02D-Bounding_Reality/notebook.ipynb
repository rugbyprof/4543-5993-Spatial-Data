# %% [markdown]
# # 02D — Editing & Simplifying Spatial Data
#
# ## Big Idea
#
# Spatial data does not represent reality — it represents **decisions about reality**.
# ## 0️⃣ Why Editing Exists
#
# Reflection:
# - Why can’t spatial data include every detail?
# - Who decides what gets removed?
# ## 1️⃣ Simplification and Meaning
#
# Reflection:
# - What happens when vertices are removed from a shape?
# - Does location change if shape changes?
# ## 2️⃣ Editing as Abstraction
#
# Reflection:
# - What details matter at city scale vs campus scale?
# - Why is abstraction necessary?
# ## 3️⃣ When Editing Goes Wrong
#
# Reflection:
# - How can simplification mislead?
# - Why is intent important?
# ## 4️⃣ Introspective Check
#
# Answer in your own words:
# - Why is spatial editing unavoidable?
# - How does simplification embed assumptions?
# - When does editing cross into manipulation?

# %% [markdown]
# # 02F — Spatial Thinking Synthesis & Check
#
# ## Big Idea
#
# **Spatial thinking is a habit, not a tool.**
#
# This notebook asks you to connect ideas from the entire Raw Spatial Data module.

# %% [markdown]
# ## 0️⃣ Looking Back
#
# So far, you have explored:
# - coordinates and reference
# - distance assumptions
# - scale and resolution
# - editing and simplification
# - failure modes
#
# This lesson connects them.

# %% [markdown]
# ## 1️⃣ Connecting Concepts
#
# ### Reflection
# - How do assumptions affect distance?
# - How does scale affect meaning?
# - Why does editing change interpretation?

# %% [markdown]
# ## 2️⃣ Thinking Without Tools
#
# You should be able to explain spatial reasoning **without mentioning software**.
#
# ### Reflection
# - What does it mean to think spatially?
# - Why are tools secondary?

# %% [markdown]
# ## 3️⃣ Scenario Synthesis
#
# Consider a dataset that:
# - plots correctly
# - uses valid coordinates
# - answers the wrong question
#
# ### Reflection
# - What likely went wrong?
# - Which concepts explain the failure?

# %% [markdown]
# ## 4️⃣ Final Introspective Check
#
# Answer thoughtfully:
# - Which concept was hardest?
# - Which mistake are you now least likely to make?
# - How will this change how you trust spatial results?
